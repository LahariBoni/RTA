# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_score, StratifiedKFold, KFold
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
data = pd.read_csv("C:\\Users\\Admin\\Desktop\\Proj\\RTA\\Dataset\\RTA Dataset.csv")

# %% [markdown]
# EDA

# %%
data.shape
# Out:
# (12316, 32)

# %%
data.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
data.describe(include=["O"]).T
# Out:
#                          count unique  \
# Time                     12316   1074
# Day_of_week              12316      7
# Age_band_of_driver       12316      5
# Sex_of_driver            12316      3
# Educational_level        11575      7
# Vehicle_driver_relation  11737      4
# Driving_experience       11487      7
# Type_of_vehicle          11366     17
# Owner_of_vehicle         11834      4
# Service_year_of_vehicle   8388      6
# Defect_of_vehicle         7889      3
# Area_accident_occured    12077     14
# Lanes_or_Medians         11931      7
# Road_allignment          12174      9
# Types_of_Junction        11429      8
# Road_surface_type        12144      5
# Road_surface_conditions  12316      4
# Light_conditions         12316      4
# Weather_conditions       12316      9
# Type_of_collision        12161     10
# Vehicle_movement         12008     13
# Casualty_class           12316      4
# Sex_of_casualty          12316      3
# ...

# %%
data.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
data["Time"]=pd.to_datetime(data["Time"])
data["Hour"] = data["Time"].dt.hour
data["Minutes"] = data["Time"].dt.minute
data.drop("Time",axis=1,inplace=True)

# %%
sns.countplot(x=data["Accident_severity"])
# Out:
# <AxesSubplot:xlabel='Accident_severity', ylabel='count'>

# %%
# cols = ["Day_of_week",               
# "Age_band_of_driver",          
# "Sex_of_driver",              
# "Educational_level",            
# "Vehicle_driver_relation",      
# "Driving_experience",          
# "Type_of_vehicle",            
# "Owner_of_vehicle",           
# "Service_year_of_vehicle",     
# "Defect_of_vehicle",            
# "Area_accident_occured",      
# "Lanes_or_Medians",         
# "Road_allignment",             
# "Types_of_Junction",         
# "Road_surface_type",           
# "Road_surface_conditions",     
# "Light_conditions",            
# "Weather_conditions",          
# "Type_of_collision",          
# "Number_of_vehicles_involved",  
# "Number_of_casualties",        
# "Vehicle_movement",            
# "Casualty_class",             
# "Sex_of_casualty",            
# "Age_band_of_casualty",       
# "Casualty_severity",           
# "Work_of_casuality",            
# "Fitness_of_casuality",         
# "Pedestrian_movement",          
# "Cause_of_accident",           
# "Hour","Minutes"
# ]

# for col in cols:
#     p=sns.countplot(y=data[col])
#     plt.show()

# %%
data.nunique()
# Out:
# Day_of_week                     7
# Age_band_of_driver              5
# Sex_of_driver                   3
# Educational_level               7
# Vehicle_driver_relation         4
# Driving_experience              7
# Type_of_vehicle                17
# Owner_of_vehicle                4
# Service_year_of_vehicle         6
# Defect_of_vehicle               3
# Area_accident_occured          14
# Lanes_or_Medians                7
# Road_allignment                 9
# Types_of_Junction               8
# Road_surface_type               5
# Road_surface_conditions         4
# Light_conditions                4
# Weather_conditions              9
# Type_of_collision              10
# Number_of_vehicles_involved     6
# Number_of_casualties            8
# Vehicle_movement               13
# Casualty_class                  4
# Sex_of_casualty                 3
# Age_band_of_casualty            6
# Casualty_severity               4
# Work_of_casuality               7
# ...

# %%
data_severity = data["Casualty_severity"] + data["Accident_severity"]

# %%
pd.DataFrame(data_severity).head(5)
# Out:
#                  0
# 0  naSlight Injury
# 1  naSlight Injury
# 2  3Serious Injury
# 3   3Slight Injury
# 4  naSlight Injury

# %%
data.isna().sum()
# Out:
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# ...

# %%
# impute_columns = []

# for x in data.isna().sum().index:
#     if data.isna().sum()[x] != 0:
#         impute_columns.append(x)

# impute_columns = impute_columns.tolist()

impute_columns = [x for x in data.isna().sum() [data.isna().sum() != 0].index.tolist()]

# %%
impute_columns
# Out:
# ['Educational_level',
#  'Vehicle_driver_relation',
#  'Driving_experience',
#  'Type_of_vehicle',
#  'Owner_of_vehicle',
#  'Service_year_of_vehicle',
#  'Defect_of_vehicle',
#  'Area_accident_occured',
#  'Lanes_or_Medians',
#  'Road_allignment',
#  'Types_of_Junction',
#  'Road_surface_type',
#  'Type_of_collision',
#  'Vehicle_movement',
#  'Work_of_casuality',
#  'Fitness_of_casuality']

# %%
for feature in impute_columns:
    mode = data[feature].mode()[0]
    data[feature] = data[feature].fillna(mode)

# %%
data.isnull().sum()
# Out:
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# Fitness_of_casuality           0
# ...

# %%
# Creating a sample DataFrame
# data = {'Age': [25, 30, 25, 35, 30],
#         'Salary': [50000, 60000, 55000, 75000, 70000]}
# df = pd.DataFrame(data)

# # List of features
# feats = ['Age', 'Salary']

# # Loop over each feature
# for feat in feats:
#     feat_val = list(np.arange(df[feat].nunique()))
#     print(f"Unique values for '{feat}': {feat_val}")

def label_encoder(data,features):
    for feature in features:
        feature_value = list(np.arange(data[feature].nunique()))
        feature_keys = list(data[feature].sort_values().unique())
        feature_dict = dict(zip(feature_keys,feature_value))
        data[feature] = data[feature].map(feature_dict)
    return data

# %%
data = label_encoder(data,data.drop("Accident_severity",axis=1).columns)
data.shape
# Out:
# (12316, 33)

# %%
data
# Out:
#        Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                1                   0              1                  0
# 1                1                   1              1                  4
# 2                1                   0              1                  4
# 3                3                   0              1                  4
# 4                3                   0              1                  4
# ...            ...                 ...            ...                ...
# 12311            6                   1              1                  4
# 12312            3                   4              1                  1
# 12313            3                   2              1                  4
# 12314            3                   0              0                  4
# 12315            3                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.drop("Accident_severity",axis=1).corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # SPlitting the Data

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop("Accident_severity",axis=1)

# %%
X
# Out:
#        Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                1                   0              1                  0
# 1                1                   1              1                  4
# 2                1                   0              1                  4
# 3                3                   0              1                  4
# 4                3                   0              1                  4
# ...            ...                 ...            ...                ...
# 12311            6                   1              1                  4
# 12312            3                   4              1                  1
# 12313            3                   2              1                  4
# 12314            3                   0              0                  4
# 12315            3                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# ...

# %%
y = data["Accident_severity"]

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(X_train.shape,X_test.shape, y_train.shape,y_test.shape)
# Out:
# (8621, 32) (3695, 32) (8621,) (3695,)

# %% [markdown]
# # Sampling TEchniques

# %%
from imblearn.over_sampling import SMOTE

# %%
over_sampling = SMOTE()
X_train,y_train = over_sampling.fit_resample(X_train,y_train)

# %%
y_train.shape
# Out:
# (21972,)

# %%
y_test.shape
# Out:
# (3695,)

# %%
y_test = label_encoder(pd.DataFrame(y_test, columns = ['Accident_severity']), pd.DataFrame(y_test, columns = ['Accident_severity']).columns)['Accident_severity']
y_train = label_encoder(pd.DataFrame(y_train, columns = ['Accident_severity']), pd.DataFrame(y_train, columns = ['Accident_severity']).columns)['Accident_severity']

# %%
y_test.shape
# Out:
# (3695,)

# %% [markdown]
# # BaseLine Modelling

# %%
def modelling(X_train,y_train,X_test,y_test, **kwargs):
    acc_scores = {}
    models = []
    if "xgb" in kwargs.keys() and kwargs["xgb"]:
        xgb = XGBClassifier()
        xgb.fit(X_train,y_train)
        y_pred = xgb.predict(X_test)
        acc_scores["xgb"] = [accuracy_score(y_test, y_pred)]
        models.append(xgb)

    if "rf" in kwargs.keys() and kwargs["rf"]:
        rf = RandomForestClassifier()
        rf.fit(X_train,y_train)
        y_pred = rf.predict(X_test)
        acc_scores["rf"] = accuracy_score(y_test,y_pred)
        models.append(rf)

    if "extree" in kwargs.keys() and kwargs["extree"]:
        extree = ExtraTreesClassifier()
        extree.fit(X_train,y_train)
        y_pred = extree.predict(X_test)
        acc_scores["extree"] = accuracy_score(y_test,y_pred)
        models.append(extree)
    
    return acc_scores, models

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (21972, 32) (3695, 32) (21972,) (3695,)

# %%
acc_scores, models = modelling(X_train,y_train,X_test,y_test,xgb=True,rf=True,extree=True)

# %%
print(acc_scores)
# Out:
# {'xgb': [0.8070365358592693], 'rf': 0.7907983761840325, 'extree': 0.8138024357239513}

# %%
def model_performance(model, y_test , y_hat):
    confusion_mat = confusion_matrix(y_test , y_hat)
    Accuracy = accuracy_score(y_test , y_hat)
    F1_score = f1_score(y_test,y_hat,average='weighted')
    Recall = recall_score(y_test , y_hat,average='weighted')

    show_metrics = pd.DataFrame(data=[[Accuracy , Recall, F1_score]])
    show_metrics = show_metrics.T

    print(show_metrics)

# %%
extree = ExtraTreesClassifier()
extree.fit(X_train,y_train)
y_pred = extree.predict(X_test)

# %%
extree.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
model_performance(extree,y_test,y_pred)
# Out:
#           0
# 0  0.814073
# 1  0.814073
# 2  0.773542

# %%
# params = {
#  'ccp_alpha': [0.0,0.5],
#  'criterion': ['gini'],
#  'max_depth': [5,10],
#  'min_samples_split': [2],
#  'n_estimators': range(150,500,50),
# }

# gridkfold = KFold(n_splits=5, shuffle = True, random_state=42).split(X=X_train,y=y_train)

# extree_estimator = ExtraTreesClassifier()

# gsearch = GridSearchCV(
#     estimator=extree_estimator,
#     param_grid=  params,
#     scoring="f1_weighted",
#     n_jobs=1,
#     cv = gridkfold,
#     verbose=1
# )

# extree_model = gsearch.fit(X=X_train,y = y_train)

# %%
# gkf2 = KFold(n_splits=3, shuffle=True, random_state=101).split(X=X_train, y=y_train)

# params2 = {
#     'max_depth': [11,15],
#     'min_samples_split': [2,3],
#     'class_weight': ['balanced', None],

# }

# extree2 = ExtraTreesClassifier(ccp_alpha = 0.0,
#                                 criterion = 'gini',
#                                 max_depth = 11,
#                                 min_samples_split = 3)

# gsearch2 = GridSearchCV(
#     estimator= extree2,
#     param_grid= params2,
#     scoring='f1_weighted',
#     n_jobs=-1,
#     cv=gkf2,
#     verbose=3,
# )

# extree_model2 = gsearch2.fit(X=X_train, y=y_train)

# (gsearch2.best_params_, gsearch2.best_score_)

# %%
X_train

# %%
extree_tuned = ExtraTreesClassifier(ccp_alpha = 0.0,
                                criterion = 'gini',
                                min_samples_split = 2,
                                class_weight = 'balanced',
                                max_depth = 15,
                                n_estimators = 400)

extree_tuned.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(class_weight='balanced', max_depth=15, n_estimators=400)

# %%
print(extree_tuned.feature_importances_)
# Out:
# [0.05060607 0.05426073 0.01540412 0.02721264 0.02860528 0.04089644
#  0.0286716  0.01976081 0.03239214 0.0017619  0.02474346 0.03497837
#  0.01282768 0.03939186 0.01059881 0.03990592 0.06697236 0.01589102
#  0.03091404 0.06041298 0.06211971 0.01825369 0.03240911 0.03745403
#  0.02746824 0.02321535 0.02612003 0.00184191 0.01114384 0.03437482
#  0.03726424 0.05212679]

# %%
feature_names = list(X.columns)
feature_names
# Out:
# ['Day_of_week',
#  'Age_band_of_driver',
#  'Sex_of_driver',
#  'Educational_level',
#  'Vehicle_driver_relation',
#  'Driving_experience',
#  'Type_of_vehicle',
#  'Owner_of_vehicle',
#  'Service_year_of_vehicle',
#  'Defect_of_vehicle',
#  'Area_accident_occured',
#  'Lanes_or_Medians',
#  'Road_allignment',
#  'Types_of_Junction',
#  'Road_surface_type',
#  'Road_surface_conditions',
#  'Light_conditions',
#  'Weather_conditions',
#  'Type_of_collision',
#  'Number_of_vehicles_involved',
#  'Number_of_casualties',
#  'Vehicle_movement',
#  'Casualty_class',
#  'Sex_of_casualty',
#  'Age_band_of_casualty',
#  'Casualty_severity',
#  'Work_of_casuality',
#  'Fitness_of_casuality',
#  'Pedestrian_movement',
#  'Cause_of_accident',
#  'Hour',
#  'Minutes']

# %%
feat_importances = pd.Series(extree_tuned.feature_importances_, index=X.columns)
plt.figure(figsize=(12,12))
myexplode = [0.12,0,0,0,0,0,0,0,0,0]
plt.pie(feat_importances.nlargest(10),labels=feat_importances.nlargest(10).index, autopct='%.0f%%',explode= myexplode,
        textprops={'fontsize': 16})
centre_circle = plt.Circle((0,0),0.10,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Important features considered by Extra Trees Classifier',fontsize=20)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_2340/2258610551.py:4: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   plt.pie(feat_importances.nlargest(10),labels=feat_importances.nlargest(10).index, autopct='%.0f%%',explode= myexplode,

# %%
extree_tuned
# Out:
# ExtraTreesClassifier(class_weight='balanced', max_depth=15, n_estimators=400)

# %%
# Step 3: Get Feature Importances
feature_importances = extree_tuned.feature_importances_

# Step 4: Get Feature Names
feature_names = list(X.columns)  # Assuming X is a DataFrame with column names

# Create a DataFrame to display feature importances
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
feature_importance_df
# Out:
#                         Feature  Importance
# 0                   Day_of_week    0.050606
# 1            Age_band_of_driver    0.054261
# 2                 Sex_of_driver    0.015404
# 3             Educational_level    0.027213
# 4       Vehicle_driver_relation    0.028605
# 5            Driving_experience    0.040896
# 6               Type_of_vehicle    0.028672
# 7              Owner_of_vehicle    0.019761
# 8       Service_year_of_vehicle    0.032392
# 9             Defect_of_vehicle    0.001762
# 10        Area_accident_occured    0.024743
# 11             Lanes_or_Medians    0.034978
# 12              Road_allignment    0.012828
# 13            Types_of_Junction    0.039392
# 14            Road_surface_type    0.010599
# 15      Road_surface_conditions    0.039906
# 16             Light_conditions    0.066972
# 17           Weather_conditions    0.015891
# 18            Type_of_collision    0.030914
# 19  Number_of_vehicles_involved    0.060413
# ...

# %%
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
import joblib

# Assuming 'X' is your original feature matrix and 'y' is your target variable
# X should contain all features initially

# Step 1: Subset Your Data
selected_features = ['Minutes', 'Day_of_week', 'Driving_experience', 'Road_surface_conditions',
                     'Types_of_Junction', 'Sex_of_casualty', 'Age_band_of_driver',
                     'Number_of_vehicles_involved', 'Number_of_casualties', 'Light_conditions']

X_subset = X[selected_features]

# Step 2: Split Your Data
X_train, X_test, y_train, y_test = train_test_split(X_subset, y, test_size=0.2, random_state=42)

# Step 3: Train Your Model
model_subset = ExtraTreesClassifier()
model_subset.fit(X_train, y_train)

# Step 4: Save the Model
joblib.dump(model_subset, 'model_subset.joblib')
# Out:
# ['model_subset.joblib']
